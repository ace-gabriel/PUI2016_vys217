# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
DFDATA = os.getenv('DFDATA')
print DFDATA
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
file_df = pd.read_csv(DFDATA + "/kku6-nxdu/1414245945/kku6-nxdu")

# %%
type(file_df)
# Out:
# pandas.core.frame.DataFrame

# %%
file_df.head(10)
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
# 5              10006                   6             2            0.33
# 6              10007                   1             0            0.00
# 7              10009                   2             0            0.00
# 8              10010                   0             0            0.00
# 9              10011                   3             2            0.67
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# ...

# %%
items = ['JURISDICTION NAME','COUNT PARTICIPANTS']
file_df.drop( file_df.columns[2:], axis=1, inplace= True )
file_df.head(10)
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS
# 0              10001                  44
# 1              10002                  35
# 2              10003                   1
# 3              10004                   0
# 4              10005                   2
# 5              10006                   6
# 6              10007                   1
# 7              10009                   2
# 8              10010                   0
# 9              10011                   3

# %%
# file_df.plot(x = 'JURISDICTION NAME', y = 'COUNT PARTICIPANTS', kind='scatter', title='Demographic Statistics By Zip Code')

f_plot = file_df.plot.scatter(x='JURISDICTION NAME', y='COUNT PARTICIPANTS', title='No. of Participants per Jurisdiction', 
                     label='Count of Participant')
f_plot.text(8000,-130 , 'Figure 1: Demographic Statistics By Jurisdiction', fontsize = '12')
